# %% [markdown]
# # 1) Directory file creation variables

# %% [markdown]
# _Foreword_
#
# This file contains all the files related to the creation of variables and data. The function of each file is explained above the cell containing the command to run the file. Running the whole directy file takes more than a day.

# %% [markdown]
# <div class="alert-info">
# 1.1. Scraping, filtering and formating the raw data.
# </div>

# %% [markdown]
# This file downloads all the data related to our list of concepts present on OpenAlex making a request.

# %%
# %run ./scraping_data_from_Open_Alex.ipynb
# Out:
#   0%|                                                                                           | 0/27 [00:00<?, ?it/s]
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %% [markdown]
# This file filters the raw data obtained in the previous file. On the one hand it takes only the information we want while
#  on the other hand it eliminates all papers which do not correspond to our research. For example, it takes only the paper published between 2002 and 2022, papers which present authors and a title, etc.

# %%
# %run ./filtering_data.ipynb
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 27/27 [1:25:19<00:00, 189.60s/it]
# Papers with missing referenced works: 113536
# Papers with missing abstracts:63903
# Papers with missing id:0
# Papers with missing titles:74
# Papers with missing authors:7486
# Papers with missing concepts:0
# Papers with missing publication date:0
# Papers with missing citing works: 0

# %% [markdown]
# This file transforms the filtered data obtained above in a pandas dataframe.

# %%
# %run ./data_to_pandas.ipynb
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 285716/285716 [00:00<00:00, 2285688.76it/s]
# In my dataset, there are 285716 papers.

# %% [markdown]
# The file below do the exploration of the full data and clean the whole data in different ways.

# %%
# %run ../exploratory_analysis/dataexploration_full_data.ipynb
# Out:
# <marquee style='width: 30%; color: brown;'><b>Let us start data exploration!</b></marquee>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# The number of duplicates is: 102384
# There are 0.09427859224558578 % of duplicates in my dataset.
# There are 285716 of papers in my database.
# There are 228321 papers with abstracts in my database.
# There are 285716 of papers in my database
# There are 142297 papers with referenced works in my database
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 27/27 [02:44<00:00,  6.08s/it]
# ['https://openalex.org/W4207024185', 'https://openalex.org/W4207002470']
# ['https://openalex.org/W2992377096', 'https://openalex.org/W2544547184']
# ['https://openalex.org/W3002425247', 'https://openalex.org/W4283656691']
# ['https://openalex.org/W2463316518', 'https://openalex.org/W109204167']
# ...

# %% [markdown]
# <div class="alert-info">
# 1.2. Creating the several variables I will use for later.
# </div>

# %% [markdown]
# This file creates a database of citations. This has the form of a dataframe with these columns: 'citing_paper', 'cited_paper', 'publication_date', 'month', 'year'.

# %%
# %run ./dfcitbasic.ipynb
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [01:38<00:00,  2.04it/s]

# %% [markdown]
# This file extracts all the keywords from the titles and the abstract of the papers and turns it into a database of keywords.
#  This has the form of a dataframe with these columns: 'paper', 'keyword', 'cosine_similarity', 'publication_date', 'year', 'month'.

# %%
# %run ./dfkeywords.ipynb
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████| 131120/131120 [15:42<00:00, 139.10it/s]

# %% [markdown]
#  This file creates a database of containing all the information about the concepts and the score of attribution to concepts.
#   This has the form of a dataframe with these columns: 'paper', 'technologies', 'score', 'publication_date', 'year', 'month'.

# %%
# %run ./dfconcepts.ipynb
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [03:32<00:00,  1.06s/it]

# %% [markdown]
# This file creates a database of citations count. This has the form of a dataframe with these columns: 'paper', 'year', 'month',
#  'cituptothistime_year', 'cituptothistime_month', 'citforthemonth', 'citfortheyear'.

# %%
# %run ./dffinalcit.ipynb
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [38:14<00:00, 114.72s/it]

# %% [markdown]
#  This file simply adds a column 'author' to the file above, which makes it easier to compute the h-indices for each author.

# %%
# %run ./dfcit_author.ipynb
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [10:35<00:00, 31.76s/it]

# %% [markdown]
# This file creates a database of h-indices. This has the form of a dataframe with these columns: 'author', 'year', 'month',
#  'yearly_H_index_notincremental', 'yearly_H_index_incremental', 'monthly_H_index_incremental', 'monthly_H_index_notincremental'.

# %%
# %run ./df_h_indices.ipynb
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 20/20 [1:29:33<00:00, 268.68s/it]

# %% [markdown]
# This file creates several databases aiming at measuring the importance of keywords over all the papers.

# %%
# %run ./auxiliarydf_viz.ipynb
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 30878/30878 [20:03<00:00, 25.66it/s]
