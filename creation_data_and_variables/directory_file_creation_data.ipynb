# %% [markdown]
# # 1) Directory file creation variables

# %% [markdown]
# In this file, we run all the python files related to the creation of variables and data, starting by scrapping the data from OpenAlex. It takes approximatively 30 hours to run.

# %% [markdown]
# <div class="alert-info">
# 1.1. Scraping, filtering and formating the raw data.
# </div>

# %%
# %run ./scraping_data_from_Open_Alex.ipynb
# Out:
#   0%|                                                                                           | 0/27 [00:00<?, ?it/s]
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
# %run ./filtering_data.ipynb

# %%
# %run ./data_to_pandas.ipynb

# %%
# %run ../exploratory_analysis/dataexploration_full_data.ipynb

# %% [markdown]
# <div class="alert-info">
# 1.2. Creating the several variables I will use for later.
# </div>

# %%
# %run ./dfcitbasic.ipynb

# %%
# %run ./dfkeywords.ipynb

# %%
# %run ./dfconcepts.ipynb

# %%
# %run ./dffinalcit.ipynb

# %%
# %run ./dfcit_author.ipynb

# %%
# %run ./df_h_indices.ipynb

# %%
# %run ./auxiliarydf_viz.ipynb
